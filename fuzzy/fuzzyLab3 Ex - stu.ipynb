# %% [markdown]
# # 🧪 Fuzzy Logic Lab – Focused Exercises
#
# **Instructions:**
# - Answer using code only
# - Make sure plots are clear
# - Use different colors where needed
# - Pay attention to parameter order

# %% [markdown]
# Add the necessary libraries

# %%
# Importing necessary libraries

# %% [markdown]
# # Q1: Gaussian Functions:
# Write and plot two Gaussian membership functions:
#
# First function: sigma (1) and mean (2)
#
# Second function: sigma (4) and mean (-3)

# %%
# Write your code here

# %% [markdown]
# ## Q2: Projection on Gaussian Functions
#
# For the previous two functions, compute and plot the membership degree for x = 6.

# %%
# Write your code here

# %% [markdown]
# ## Q3: Bell, Triangular, Trapezoidal + Operations:
# Define the following membership functions over the domain [-7, 6]:
#
# Bell function
# Triangular function
# Trapezoidal function
#
# In one drawing

# %%
# Write your code here

# %% [markdown]
# Then:
#
# Plot all three functions
# Compute and plot:
# Intersection
# Union
# Complement of the intersection
#
# Compute (intersection, union, complement) For the previous three functions together and Plot the results (Each one is a drawing on its own using plt.subplot).

# %%
# Write your code here

# %% [markdown]
# Finally:
#
# On the union graph, annotate the membership degrees at:
# x = -3
# x = 2
# using plt.text

# %%
# Write your code here

# %% [markdown]
# ## Q4: Alpha-cut
#
# Compute the alpha-cut for alpha value 0.55. Visualize cut. (for your previou fuzzy union)

# %%
# Write your code here
