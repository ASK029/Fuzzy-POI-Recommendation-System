# %% [markdown]
# ### Extracting Interactive Map from Itinerary JSON files
# Using `folium` for detailed interactive maps with clickable markers and routing.

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: jinja2>=2.9 in D:\Projects\tripsage-langchain-pipeline\venv\Lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in D:\Projects\tripsage-langchain-pipeline\venv\Lib\site-packages (from folium) (2.4.2)
# Requirement already satisfied: requests in D:\Projects\tripsage-langchain-pipeline\venv\Lib\site-packages (from folium) (2.32.5)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2026.3.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in D:\Projects\tripsage-langchain-pipeline\venv\Lib\site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\Projects\tripsage-langchain-pipeline\venv\Lib\site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in D:\Projects\tripsage-langchain-pipeline\venv\Lib\site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\Projects\tripsage-langchain-pipeline\venv\Lib\site-packages (from requests->folium) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in D:\Projects\tripsage-langchain-pipeline\venv\Lib\site-packages (from requests->folium) (2026.1.4)
# Downloading folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Downloading branca-0.8.2-py3-none-any.whl (26 kB)
# Downloading xyzservices-2026.3.0-py3-none-any.whl (94 kB)
# Installing collected packages: xyzservices, branca, folium
#
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    ---------------------------------------- 3/3 [folium]
#
# Successfully installed branca-0.8.2 folium-0.20.0 xyzservices-2026.3.0

# %%
import json
import folium

# 1. Load the data
original_path = "itenerary.json"
optimized_path = "tsp_results1.json"
optimized_geo_path = "tsp_results2.json"

original_itinerary = json.load(open(original_path))
optimized_itinerary = json.load(open(optimized_path))
optimized_geo_itinerary = json.load(open(optimized_geo_path))

# 2. Function to build the Folium Map
def create_folium_map(data, title='itinerary'):
    itinerary = data.get(title, {})
    
    points = []
    # Folium supports specific colors: red, blue, green, purple, orange, darkred, lightred, beige, darkblue, darkgreen, cadetblue, darkpurple, white, pink, lightblue, lightgreen, gray, black, lightgray
    day_colors = {'Day1': 'red', 'Day2': 'green', 'Day3': 'blue'}
    
    for day_name, day_content in itinerary.items():
        for time_slot, pois in day_content.items():
            for poi in pois:
                points.append({
                    'lat': poi['location']['lat'] if title == 'itinerary' else poi['latitude'],
                    'lon': poi['location']['lon'] if title == 'itinerary' else poi['longitude'],
                    'name': poi['place'],
                    'day': day_name,
                    'time': time_slot,
                    'color': day_colors.get(day_name, 'gray')
                })

    if not points:
        print(f"No points found for '{title}'")
        return None

    unique_points = []
    seen = set()
    for p in points:
        key = (p['lat'], p['lon'], p['name'])
        if key not in seen:
            seen.add(key)
            unique_points.append(p)
            
    avg_lat = sum(p['lat'] for p in unique_points) / len(unique_points)
    avg_lon = sum(p['lon'] for p in unique_points) / len(unique_points)
    
    # Create base map
    m = folium.Map(location=[avg_lat, avg_lon], zoom_start=12, tiles='CartoDB positron')
    
    # Draw route lines
    route_coords = [[p['lat'], p['lon']] for p in points]
    folium.PolyLine(
        route_coords, 
        color="black", 
        weight=2.5, 
        opacity=0.6,
        dash_array='5, 5'
    ).add_to(m)
    
    # Add interactive markers
    for idx, p in enumerate(unique_points):
        popup_html = f"""
        <div style='min-width: 150px; font-family: sans-serif;'>
            <h4 style='margin-bottom: 5px;'>{idx + 1}. {p['name']}</h4>
            <hr style='margin: 5px 0px;'>
            <b>Day:</b> {p['day']}<br>
            <b>Time:</b> {p['time']}
        </div>
        """
        
        folium.Marker(
            location=[p['lat'], p['lon']],
            popup=folium.Popup(popup_html, max_width=300),
            tooltip=f"Click for details: {p['name']}",
            icon=folium.Icon(color=p['color'], icon='info-sign')
        ).add_to(m)
        
    return m

# %%
print("Generating original itinerary map...")
original_map = create_folium_map(original_itinerary, title='itinerary')
original_map
# Out:
# Generating original itinerary map...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5048298842de84d2aa59547da22b4677 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5048298842de84d2aa59547da22b4677&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5048298842de84d2aa59547da22b4677 = L.map(
#                 &quot;map_5048298842de84d2aa59547da22b4677&quot;,
#                 {
#                     center: [55.730636363636364, 37.609935],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_768af25b3462b49b2a1e73e72b88252d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_768af25b3462b49b2a1e73e72b88252d.addTo(map_5048298842de84d2aa59547da22b4677);
#
#
#             var poly_line_aba9c2a31218aac1a3b1f13dabce3789 = L.polyline(
#                 [[55.755825, 37.6173], [55.75528, 37.61582], [55.75444, 37.621056], [55.712, 37.6209], [55.712082, 37.620792], [55.73507, 37.606388], [55.728367, 37.60129], [55.715656, 37.586414], [55.712, 37.6209], [55.74811, 37.53849], [55.66015, 37.662205], [55.712, 37.6209], [55.76002, 37.61863]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.6, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_5048298842de84d2aa59547da22b4677);
#
#
#             var marker_6446a20032a9c6b8c06fae343b1e770d = L.marker(
#                 [55.755825, 37.6173],
#                 {
# }
#             ).addTo(map_5048298842de84d2aa59547da22b4677);
#
#
#             var icon_3d98f1ffcaa9ba529df39d603e153bb7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_71dfbf768ac89a4d04ed1222e0525d08 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_4ba21817fe5056349aaffcd3530406e2 = $(`&lt;div id=&quot;html_4ba21817fe5056349aaffcd3530406e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;div style=&#x27;min-width: 150px; font-family: sans-serif;&#x27;&gt;             &lt;h4 style=&#x27;margin-bottom: 5px;&#x27;&gt;1. Moscow Metro&lt;/h4&gt;             &lt;hr style=&#x27;margin: 5px 0px;&#x27;&gt;             &lt;b&gt;Day:&lt;/b&gt; Day1&lt;br&gt;             &lt;b&gt;Time:&lt;/b&gt; Morning         &lt;/div&gt;         &lt;/div&gt;`)[0];
#                 popup_71dfbf768ac89a4d04ed1222e0525d08.setContent(html_4ba21817fe5056349aaffcd3530406e2);
#
#
#
#         marker_6446a20032a9c6b8c06fae343b1e770d.bindPopup(popup_71dfbf768ac89a4d04ed1222e0525d08)
#         ;
#
#
#
#
#             marker_6446a20032a9c6b8c06fae343b1e770d.bindTooltip(
#                 `&lt;div&gt;
#                      Click for details: Moscow Metro
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_6446a20032a9c6b8c06fae343b1e770d.setIcon(icon_3d98f1ffcaa9ba529df39d603e153bb7);
#
#
#             var marker_2e8fddb53ea3413cf51aebb3ca8f60c2 = L.marker(
#                 [55.75528, 37.61582],
#                 {
# }
#             ).addTo(map_5048298842de84d2aa59547da22b4677);
#
#
#             var icon_5161b5925917d91b0e6c98e5ec814ac5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3abc5daf3485a06d6cef9e55672843ec = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_630a73e4e90e1e478840f09497aca072 = $(`&lt;div id=&quot;html_630a73e4e90e1e478840f09497aca072&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;div style=&#x27;min-width: 150px; font-family: sans-serif;&#x27;&g

# %%
print("Generating optimized itinerary map...")
# Ensure the title key matches the root JSON property inside tsp_results1.json
optimized_map = create_folium_map(optimized_itinerary, title='optimized_itinerary')
optimized_map
# Out:
# Generating optimized itinerary map...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5ce08478f28b14770a1a508ab0e7c01 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5ce08478f28b14770a1a508ab0e7c01&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a5ce08478f28b14770a1a508ab0e7c01 = L.map(
#                 &quot;map_a5ce08478f28b14770a1a508ab0e7c01&quot;,
#                 {
#                     center: [55.727698, 37.6090655],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ca58de77b1541371fd176f77f4a3daa = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ca58de77b1541371fd176f77f4a3daa.addTo(map_a5ce08478f28b14770a1a508ab0e7c01);
#
#
#             var poly_line_cf879bfcf481cf5e32c2996acee1c58b = L.polyline(
#                 [[55.755825, 37.6173], [55.75528, 37.61582], [55.75444, 37.621056], [55.73507, 37.606388], [55.728367, 37.60129], [55.712082, 37.620792], [55.712, 37.6209], [55.712, 37.6209], [55.712, 37.6209], [55.66015, 37.662205], [55.715656, 37.586414], [55.74811, 37.53849]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.6, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_a5ce08478f28b14770a1a508ab0e7c01);
#
#
#             var marker_dc3690cf05e12dc13ca406c6f6c7846f = L.marker(
#                 [55.755825, 37.6173],
#                 {
# }
#             ).addTo(map_a5ce08478f28b14770a1a508ab0e7c01);
#
#
#             var icon_6d37157f2a32828a72491fe2bc2d9ed7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_afbff3461e50d8d38bdde29050d7e252 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_fe4fced3557140d924d0bfe9238e0b42 = $(`&lt;div id=&quot;html_fe4fced3557140d924d0bfe9238e0b42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;div style=&#x27;min-width: 150px; font-family: sans-serif;&#x27;&gt;             &lt;h4 style=&#x27;margin-bottom: 5px;&#x27;&gt;1. Moscow Metro&lt;/h4&gt;             &lt;hr style=&#x27;margin: 5px 0px;&#x27;&gt;             &lt;b&gt;Day:&lt;/b&gt; Day1&lt;br&gt;             &lt;b&gt;Time:&lt;/b&gt; Morning         &lt;/div&gt;         &lt;/div&gt;`)[0];
#                 popup_afbff3461e50d8d38bdde29050d7e252.setContent(html_fe4fced3557140d924d0bfe9238e0b42);
#
#
#
#         marker_dc3690cf05e12dc13ca406c6f6c7846f.bindPopup(popup_afbff3461e50d8d38bdde29050d7e252)
#         ;
#
#
#
#
#             marker_dc3690cf05e12dc13ca406c6f6c7846f.bindTooltip(
#                 `&lt;div&gt;
#                      Click for details: Moscow Metro
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_dc3690cf05e12dc13ca406c6f6c7846f.setIcon(icon_6d37157f2a32828a72491fe2bc2d9ed7);
#
#
#             var marker_73cbe29cc564b323b6c411fc6a06f743 = L.marker(
#                 [55.75528, 37.61582],
#                 {
# }
#             ).addTo(map_a5ce08478f28b14770a1a508ab0e7c01);
#
#
#             var icon_1e3876b2ed1a17d71eebfd17f3dad16c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9d42e9aaaa9026626bb46382a5fcf60c = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_f5440d8c8a03adaa97cac80865fa2c6e = $(`&lt;div id=&quot;html_f5440d8c8a03adaa97cac80865fa2c6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;div style=&#x27;min-width: 150px; font-family: sans-serif;&#x27;&gt;             &lt;h4 style=&#

# %%
print("Generating optimized geoepify itinerary map...")
# Ensure the title key matches the root JSON property inside tsp_results1.json
optimized_geo_map = create_folium_map(optimized_geo_itinerary, title='optimized_itinerary')
optimized_geo_map
# Out:
# Generating optimized geoepify itinerary map...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e51c8e56a1f6017b8b71b6fc02bb4204 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e51c8e56a1f6017b8b71b6fc02bb4204&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e51c8e56a1f6017b8b71b6fc02bb4204 = L.map(
#                 &quot;map_e51c8e56a1f6017b8b71b6fc02bb4204&quot;,
#                 {
#                     center: [55.728171999999994, 37.6093465],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b5d7217de6ab22cae8825256c6542602 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b5d7217de6ab22cae8825256c6542602.addTo(map_e51c8e56a1f6017b8b71b6fc02bb4204);
#
#
#             var poly_line_47752f6f3d488c6837574ea03d92e87b = L.polyline(
#                 [[55.755825, 37.6173], [55.76002, 37.61863], [55.712, 37.6209], [55.66015, 37.662205], [55.74811, 37.53849], [55.712, 37.6209], [55.715656, 37.586414], [55.728367, 37.60129], [55.73507, 37.606388], [55.712082, 37.620792], [55.712, 37.6209], [55.75444, 37.621056]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.6, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_e51c8e56a1f6017b8b71b6fc02bb4204);
#
#
#             var marker_4b043e7ea087bbf114c69fbcc1dd5ab6 = L.marker(
#                 [55.755825, 37.6173],
#                 {
# }
#             ).addTo(map_e51c8e56a1f6017b8b71b6fc02bb4204);
#
#
#             var icon_4e125aef1467c2b2e77369dabad1d245 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d682317b69f604ae2f5586d968c652c9 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_5b46731dcfeac671d03450e8ee0ec3f5 = $(`&lt;div id=&quot;html_5b46731dcfeac671d03450e8ee0ec3f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;div style=&#x27;min-width: 150px; font-family: sans-serif;&#x27;&gt;             &lt;h4 style=&#x27;margin-bottom: 5px;&#x27;&gt;1. Moscow Metro&lt;/h4&gt;             &lt;hr style=&#x27;margin: 5px 0px;&#x27;&gt;             &lt;b&gt;Day:&lt;/b&gt; Day1&lt;br&gt;             &lt;b&gt;Time:&lt;/b&gt; Morning         &lt;/div&gt;         &lt;/div&gt;`)[0];
#                 popup_d682317b69f604ae2f5586d968c652c9.setContent(html_5b46731dcfeac671d03450e8ee0ec3f5);
#
#
#
#         marker_4b043e7ea087bbf114c69fbcc1dd5ab6.bindPopup(popup_d682317b69f604ae2f5586d968c652c9)
#         ;
#
#
#
#
#             marker_4b043e7ea087bbf114c69fbcc1dd5ab6.bindTooltip(
#                 `&lt;div&gt;
#                      Click for details: Moscow Metro
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_4b043e7ea087bbf114c69fbcc1dd5ab6.setIcon(icon_4e125aef1467c2b2e77369dabad1d245);
#
#
#             var marker_4f46df2d73075b0b9f3c7d2304cc987c = L.marker(
#                 [55.76002, 37.61863],
#                 {
# }
#             ).addTo(map_e51c8e56a1f6017b8b71b6fc02bb4204);
#
#
#             var icon_e85be498884537d1f9d0f3519763085c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_12812163280eb86b0c65d0cf669dc973 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_b4541a2fb5e8ba8020ca9990cbcc9a9a = $(`&lt;div id=&quot;html_b4541a2fb5e8ba8020ca9990cbcc9a9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;div style=&#x27;min-width: 150px; font-family: sans-serif;&#x27;&gt;             &lt;h4
