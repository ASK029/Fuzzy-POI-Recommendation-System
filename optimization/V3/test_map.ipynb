# %% [markdown]
# # V2 itinerary maps
#
# This notebook maps the original itinerary from `itinerary.json` and the optimized multi-day VRP result from `vrp_results.json`.

# %%
# !pip install folium

# %%
from pathlib import Path

from map_itineraries import (
    build_maps,
    create_folium_map,
    hotel_from_vrp,
    latest_vrp_result,
    load_json,
    optimized_vrp_routes,
    original_itinerary_routes,
)

base_dir = Path.cwd()
if not (base_dir / "itinerary.json").exists():
    base_dir = Path("optimization/V3")

original_path = base_dir / "itinerary.json"
optimized_path = base_dir / "vrp_results.json"

original_itinerary = load_json(original_path)
vrp_result = latest_vrp_result(load_json(optimized_path))
hotel_location = hotel_from_vrp(vrp_result)

hotel_location
# Out:
# {'lat': 36.1147, 'lon': -115.1728}

# %%
print("Generating original itinerary map...")
original_map = create_folium_map(
    original_itinerary_routes(original_itinerary),
    title="Original itinerary",
    hotel_location=hotel_location,
)
original_map
# Out:
# Generating original itinerary map...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_758f810096a9dddb6b6325392f1f12fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 style=&quot;position: fixed; top: 10px; left: 50px; z-index: 9999;
#                background: white; padding: 8px 12px; border: 1px solid #bbb;
#                font-family: sans-serif; margin: 0;&quot;&gt;
#         Original itinerary
#     &lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_758f810096a9dddb6b6325392f1f12fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_758f810096a9dddb6b6325392f1f12fd = L.map(
#                 &quot;map_758f810096a9dddb6b6325392f1f12fd&quot;,
#                 {
#                     center: [36.11489914285714, -115.15181314285714],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f638b1bc8b9f81b015d51721e803fc9e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f638b1bc8b9f81b015d51721e803fc9e.addTo(map_758f810096a9dddb6b6325392f1f12fd);
#
#
#             var marker_335efe94479720ae2a8ba4c1fadd2591 = L.marker(
#                 [36.1147, -115.1728],
#                 {
# }
#             ).addTo(map_758f810096a9dddb6b6325392f1f12fd);
#
#
#             var icon_8fe108fbe949ccb6d0436ecdd7c5f648 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9fe1aa9999311e7b8e3d498dd9bb12d5 = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_5ffb7b77bf8f0f6e2fa0dbbcc579b6ed = $(`&lt;div id=&quot;html_5ffb7b77bf8f0f6e2fa0dbbcc579b6ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Hotel&lt;/b&gt;&lt;br&gt;Start and end point&lt;/div&gt;`)[0];
#                 popup_9fe1aa9999311e7b8e3d498dd9bb12d5.setContent(html_5ffb7b77bf8f0f6e2fa0dbbcc579b6ed);
#
#
#
#         marker_335efe94479720ae2a8ba4c1fadd2591.bindPopup(popup_9fe1aa9999311e7b8e3d498dd9bb12d5)
#         ;
#
#
#
#
#             marker_335efe94479720ae2a8ba4c1fadd2591.bindTooltip(
#                 `&lt;div&gt;
#                      Hotel
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_335efe94479720ae2a8ba4c1fadd2591.setIcon(icon_8fe108fbe949ccb6d0436ecdd7c5f648);
#
#
#             var feature_group_2f7675dd3bfc015c51da0deb42170631 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var poly_line_40deb291f878e6f70682da81707c685d = L.polyline(
#                 [[36.1147, -115.1728], [36.082073, -115.172775], [36.112858, -115.173], [36.112244, -115.17042], [36.117783, -115.17258], [36.11212, -115.174706], [36.170727, -115.14382], [36.100136, -115.112076], [36.1147, -115.1728]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_2f7675dd3bfc015c51da0deb42170631);
#
#
#             poly_line_40deb291f878e6f70682da81707c685d.bindTooltip(
#                 `&lt;div&gt;
#                      Day1 route
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5deb0c818fea78f9f6a7c7995213a2f8 = L.marker(
#                 [36.082073, -115.172775],
#                 {
# }
#             ).addTo(feature_group_2f7675dd3bfc015c51da0deb42170631);
#
#
#             var icon_a14bd1f36b8f4c84eb2a0008c8c89eb7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3a2d016ba3b7ceb2a174b9b50d82ed33 = L.popup({
#   &quot;maxWidth&quot;: 320,
# });

# %%
print("Generating optimized VRP itinerary map...")
optimized_map = create_folium_map(
    optimized_vrp_routes(vrp_result),
    title="Optimized VRP itinerary",
    hotel_location=hotel_location,
)
optimized_map
# Out:
# Generating optimized VRP itinerary map...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f6c4e5e40a588a61222fa237177d65c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 style=&quot;position: fixed; top: 10px; left: 50px; z-index: 9999;
#                background: white; padding: 8px 12px; border: 1px solid #bbb;
#                font-family: sans-serif; margin: 0;&quot;&gt;
#         Optimized VRP itinerary
#     &lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f6c4e5e40a588a61222fa237177d65c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f6c4e5e40a588a61222fa237177d65c = L.map(
#                 &quot;map_6f6c4e5e40a588a61222fa237177d65c&quot;,
#                 {
#                     center: [36.11489914285714, -115.15181314285714],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e1e1a3516b7138963aef90d8bbb069e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3e1e1a3516b7138963aef90d8bbb069e.addTo(map_6f6c4e5e40a588a61222fa237177d65c);
#
#
#             var marker_309c80f6b059311ee1bb32e367bc4601 = L.marker(
#                 [36.1147, -115.1728],
#                 {
# }
#             ).addTo(map_6f6c4e5e40a588a61222fa237177d65c);
#
#
#             var icon_c768dd68202c81f875ecda4753cf6a2f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_bce264d2403cc9e23951e663771c244d = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_6ab57c491e894916a11d011981fa8127 = $(`&lt;div id=&quot;html_6ab57c491e894916a11d011981fa8127&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Hotel&lt;/b&gt;&lt;br&gt;Start and end point&lt;/div&gt;`)[0];
#                 popup_bce264d2403cc9e23951e663771c244d.setContent(html_6ab57c491e894916a11d011981fa8127);
#
#
#
#         marker_309c80f6b059311ee1bb32e367bc4601.bindPopup(popup_bce264d2403cc9e23951e663771c244d)
#         ;
#
#
#
#
#             marker_309c80f6b059311ee1bb32e367bc4601.bindTooltip(
#                 `&lt;div&gt;
#                      Hotel
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_309c80f6b059311ee1bb32e367bc4601.setIcon(icon_c768dd68202c81f875ecda4753cf6a2f);
#
#
#             var feature_group_7ecc63aeee8de4c8e77e121d0586c4ea = L.featureGroup(
#                 {
# }
#             );
#
#
#             var poly_line_ec4970ec61e851b92fef794be7fba5c0 = L.polyline(
#                 [[36.1147, -115.1728], [36.170727, -115.14382], [36.159775, -115.17124], [36.159775, -115.17124], [36.12764, -115.17304], [36.112858, -115.173], [36.11212, -115.174706], [36.113144, -115.17655], [36.1147, -115.1728]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_7ecc63aeee8de4c8e77e121d0586c4ea);
#
#
#             poly_line_ec4970ec61e851b92fef794be7fba5c0.bindTooltip(
#                 `&lt;div&gt;
#                      Day1 route
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_2ea1c49f669ec6b462f3fbc983d495c9 = L.marker(
#                 [36.170727, -115.14382],
#                 {
# }
#             ).addTo(feature_group_7ecc63aeee8de4c8e77e121d0586c4ea);
#
#
#             var icon_9f1e39bc2e2f59efe6ffc80ac1a27280 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_36d5f3c35975180e51f8d014f2ef1caf = L.popup({
#   &quot;maxWidth&quot;: 320,
# });

# %%
original_map, optimized_map = build_maps(
    original_path=original_path,
    optimized_path=optimized_path,
    output_dir=base_dir,
)

print("Saved original_itinerary_map.html")
print("Saved optimized_vrp_itinerary_map.html")
